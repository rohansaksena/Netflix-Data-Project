# %% [markdown]
# # Netflix Dataset

# %% [markdown]
# This is a Dataset of certain series and movies present on Netflix with information regarding:-"Show_Id", "Category","Title",	"Director", "Cast", "Country", "Release_Date", "Rating", "Duration", "Type", "Description"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime as dt
import matplotlib.pyplot as plt

# %%
netflix_df = pd.read_csv('Netflix Dataset.csv')

# %% [markdown]
# **Previewing the first 5 entries of our dataset**

# %%
netflix_df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %% [markdown]
# **Previewing the last 5 entries of our dataset**

# %%
netflix_df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7785                                              India       March 2, 2019
# 7786                                                NaN  September 25, 2020
# 7787                                          Australia    October 31, 2020
# 7788              United Kingdom, Canada, United States       March 1, 2020
#
#      Rating  Duration                                               Type  \
# 7784  TV-MA    99 min                       Dramas, International Movies
# 7785  TV-14   111 min     Dramas, International Movies, Music & Musicals
# 7786  TV-MA    44 min  Documentaries, International Movies, Music & M...
# 7787  TV-PG  1 Season                 International TV Shows, Reality TV
# 7788  TV-MA    90 min                    Documentaries, Music & Musicals
#
#                                             Description
# 7784  When Lebanon's Civil War deprives Zozo of his ...
# 7785  A scrappy but poor boy worms his way into a ty...
# 7786  In this documentary, South African rapper Nast...
# 7787  Dessert wizard Adriano Zumbo looks for the nex...
# 7788  This documentary delves into the mystique behi...

# %% [markdown]
# **Finding the rows and columns in our Dataset**

# %%
netflix_df.shape
# Out:
# (7789, 11)

# %% [markdown]
# **Finding out any null values if they exist and represent them through a heatmap**

# %%
netflix_df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(netflix_df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Finding out the data type for each variable**

# %%
netflix_df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# **Replacing all 'Directors' with Null Values to 'unknown'**

# %%
netflix_df["Director"] = netflix_df["Director"].fillna('Unknown')
netflix_df["Cast"] = netflix_df["Director"].fillna('Unknown')
netflix_df.head()
# Out:
#   Show_Id Category  Title           Director               Cast  \
# 0      s1  TV Show     3%            Unknown            Unknown
# 1      s2    Movie  07:19  Jorge Michel Grau  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan       Gilbert Chan
# 3      s4    Movie      9        Shane Acker        Shane Acker
# 4      s5    Movie     21     Robert Luketic     Robert Luketic
#
#          Country       Release_Date Rating   Duration  \
# 0         Brazil    August 14, 2020  TV-MA  4 Seasons
# 1         Mexico  December 23, 2016  TV-MA     93 min
# 2      Singapore  December 20, 2018      R     78 min
# 3  United States  November 16, 2017  PG-13     80 min
# 4  United States    January 1, 2020  PG-13    123 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          Description   (Director, Cast)
# 0  In a future where the elite inhabit an island ...            Unknown
# 1  After a devastating earthquake hits Mexico Cit...  Jorge Michel Grau
# 2  When an army recruit is found dead, his fellow...       Gilbert Chan
# 3  In a postapocalyptic world, rag-doll robots hi...        Shane Acker
# 4  A brilliant group of students become card-coun...     Robert Luketic

# %% [markdown]
# **Finding out the data from our dataset which have the 'Type' equal to "International TV Shows, TV Dramas" or "International TV Shows", "TV Dramas"**

# %%
netflix_df[netflix_df['Type'].isin(["International TV Shows, TV Dramas","International TV Shows", "TV Dramas"])]
# Out:
#      Show_Id Category                              Title Director  \
# 16       s17  TV Show                             Feb-09      NaN
# 86       s87  TV Show       21 Sarfarosh: Saragarhi 1897      NaN
# 235     s236  TV Show     A Taiwanese Tale of Two Cities      NaN
# 239     s240  TV Show              A Thousand Goodnights      NaN
# 241     s242  TV Show                   A Touch of Green      NaN
# ...      ...      ...                                ...      ...
# 7666   s7665  TV Show                 World at Your Feet      NaN
# 7701   s7700  TV Show  Yanxi Palace: Princess Adventures      NaN
# 7711   s7710  TV Show                        Yes We Can!      NaN
# 7748   s7747  TV Show                       دفعة القاهرة      NaN
# 7755   s7754  TV Show                         Yunus Emre      NaN
#
#                                                    Cast    Country  \
# 16    Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...        NaN
# 86                   Luke Kenny, Mohit Raina, Mukul Dev      India
# 235     Tammy Chen, James Wen, Peggy Tseng, Denny Huang     Taiwan
# 239   Cindy Lien, Nicholas Teo, Yao Ai-ning, Li Chun...     Taiwan
# 241   Weber Yang, Cheryl Yang, Tien Hsin, Gabriel La...     Taiwan
# ...                                                 ...        ...
# 7666  Ha Yu, Tay Ping Hui, Jeanette Aw, Elvin Ng, Yv...  Singapore
# 7701  Wang Herun, Wang Yizhe, Wang Yuwei, Xu Xiaonuo...      China
# 7711  Romeo Tan, Rebecca Lim, Sora Ma, Xu Bin, Chen ...  Singapore
# 7748  Bashar al-Shatti, Fatima Al Safi, Maram Baloch...        NaN
# 7755  Gökhan Atalay, Payidar Tüfekçioglu, Baran Akbu...     Turkey
#
#            Release_Date Rating   Duration                               Type  \
# 16       March 20, 2019  TV-14   1 Season  International TV Shows, TV Dramas
# 86     December 1, 2018  TV-14   1 Season  International TV Shows, TV Dramas
# 235    January 27, 2019  TV-MA   1 Season  International TV Shows, TV Dramas
# 239        June 1, 2019  TV-14   1 Season  International TV Shows, TV Dramas
# 241        July 1, 2020  TV-MA   1 Season  International TV Shows, TV Dramas
# ...                 ...    ...        ...                                ...
# 7666       July 1, 2017  TV-14   1 Season  International TV Shows, TV Dramas
# 7701  December 31, 2019  TV-14   1 Season  International TV Shows, TV Dramas
# 7711       July 1, 2017  TV-14   1 Season  International TV Shows, TV Dramas
# 7748     April 25, 2020  TV-14   1 Season  International TV Shows, TV Dramas
# 7755   January 17, 2017  TV-PG  2 Seasons  International TV Shows, TV Dramas
#
#                                             Description
# 16    As a psychology professor faces Alzheimer's, h...
# 86    In one of history's greatest last stands, a ba...
# 235   A Taipei doctor and a San Francisco engineer s...
# 239   To carry out her dad's wish and discover her r...
# 241   Amid the turmoil of China's civil war, familie...
# ...                                                 ...
# 7666  A group of struggling individuals are united b...
# 7701  A determined Qing dynasty princess contends wi...
# 7711  When a frustrated businessman starts his own f...
# 7748  A group of women leaves Kuwait to attend unive...
# 7755  During the Mongol invasions, Yunus Emre leaves...
#
# [147 rows x 11 columns]

# %% [markdown]
# #### Finding Duplicate data from our dataset

# %%
netflix_df[netflix_df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# #### Removing Duplicate Data from our Dataset

# %%
netflix_df.drop_duplicates(inplace=True)
netflix_df.shape #To check our changes
# Out:
# (7787, 11)

# %% [markdown]
# **What is the show Id for House of cards and who directed it ?**

# %%
netflix_df[netflix_df['Title'] =='House of Cards'] #Method 1
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  \
# 2832  A ruthless politician will stop at nothing to ...
#
#                                        (Director, Cast)
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
netflix_df[netflix_df['Title'].isin(['House of Cards'])] #Method 2
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  \
# 2832  A ruthless politician will stop at nothing to ...
#
#                                        (Director, Cast)
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %%
netflix_df[netflix_df['Title'].str.contains('House of Cards')] #Method 3
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description  \
# 2832  A ruthless politician will stop at nothing to ...
#
#                                        (Director, Cast)
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...

# %% [markdown]
# **convert object data type to datetime**

# %%
netflix_df['Release_Date'] = pd.to_datetime(netflix_df['Release_Date'])
netflix_df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %% [markdown]
# **In which year were the maximum number of shows and series were released ? show with Bargraph**

# %%
netflix_df['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2154
# 2020.0    2010
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
netflix_df['Release_Date'].dt.year.value_counts().plot(kind='bar')#Method 1
# Out:
# <AxesSubplot:>

# %%
netflix_df['Release_Years'] = netflix_df['Release_Date'].dt.year
plt.xticks(rotation=45)
sns.countplot(x='Release_Years',data=netflix_df)#Method 2
# Out:
# <AxesSubplot:xlabel='Release_Years', ylabel='count'>

# %% [markdown]
# **Number of Movies and TV Shows Present in this Dataset , represent it via Bargraph**

# %%
netflix_df['Category'].value_counts()#Unique Movie and Tv Shows
# Out:
# Movie      5379
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category',data=netflix_df,palette='Set2',lw=3,ec='black',hatch='/')#Method 1
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
netflix_df['Category'].value_counts().plot(kind='bar')#Method 2
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Show all the movies that were released in the year 2016

# %%
netflix_df[(netflix_df['Category']=='Movie')&(netflix_df['Release_Years']== 2016)]
# Out:
#      Show_Id Category                    Title  \
# 1         s2    Movie                    07:19
# 25       s26    Movie                 (T)ERROR
# 35       s36    Movie                #Rucker50
# 59       s60    Movie          1000 Rupee Note
# 62       s63    Movie               13 Cameras
# ...      ...      ...                      ...
# 7715   s7714    Movie  Yo-Kai Watch: The Movie
# 7716   s7715    Movie              Yoga Hosers
# 7728   s7727    Movie             You Carry Me
# 7739   s7738    Movie              Young Tiger
# 7772   s7771    Movie                  Zinzana
#
#                                     Director  \
# 1                          Jorge Michel Grau
# 25    Lyric R. Cabral, David Felix Sutcliffe
# 35                     Robert McCullough Jr.
# 59                            Shrihari Sathe
# 62                            Victor Zarcoff
# ...                                      ...
# 7715                             Mark Risley
# 7716                             Kevin Smith
# 7728                              Ivona Juka
# 7739                                  Mu Chu
# 7772                         Majid Al Ansari
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 25                                                  NaN
# 35                                                  NaN
# 59    Usha Naik, Sandeep Pathak, Shrikant Yadav, Gan...
# 62    PJ McCabe, Brianne Moncrief, Sarah Baldwin, Ji...
# ...                                                 ...
# 7715  Johnny Yong Bosch, Joey D'Auria, Alicyn Packar...
# 7716  Harley Quinn Smith, Lily-Rose Depp, Johnny Dep...
# 7728  Lana Baric, Vojislav Brajovic, Natasa Janjic, ...
# 7739  Qiu Yuen, Charlie Chin, Jackie Chan, Hu Chin, ...
# 7772  Ali Suliman, Saleh Bakri, Yasa, Ali Al-Jabri, ...
#
#                                     Country Release_Date Rating Duration  \
# 1                                    Mexico   2016-12-23  TV-MA   93 min
# 25                            United States   2016-06-30     NR   84 min
# 35                            United States   2016-12-01  TV-PG   56 min
# 59                                    India   2016-12-01  TV-14   89 min
# 62                            United States   2016-08-13     NR   90 min
# ...                                     ...          ...    ...      ...
# 7715                   Japan, United States   2016-12-01  TV-Y7   96 min
# 7716                          United States   2016-12-02  PG-13   88 min
# 7728  Croatia, Slovenia, Serbia, Montenegro   2016-07-01  TV-MA  157 min
# 7739                              Hong Kong   2016-11-01     NR   81 min
# 7772           United Arab Emirates, Jordan   2016-03-09  TV-MA   96 min
#
#                                               Type  \
# 1                     Dramas, International Movies
# 25                                   Documentaries
# 35                    Documentaries, Sports Movies
# 59                    Dramas, International Movies
# 62    Horror Movies, Independent Movies, Thrillers
# ...                                            ...
# 7715      Anime Features, Children & Family Movies
# 7716   Comedies, Horror Movies, Independent Movies
# 7728                  Dramas, International Movies
# 7739      Action & Adventure, International Movies
# 7772       Dramas, International Movies, Thrillers
#
#                                             Description  Release_Years
# 1     After a devastating earthquake hits Mexico Cit...         2016.0
# 25    This real-life look at FBI counterterrorism op...         2016.0
# 35    This documentary celebrates the 50th anniversa...         2016.0
# 59    After randomly receiving a handsome political ...         2016.0
# 62    Young parents-to-be Claire and Ryan move into ...         2016.0
# ...                                                 ...            ...
# 7715  Nate's special Yo-Kai Watch is missing. He tra...         2016.0
# 7716  With an all-important high school party at sta...         2016.0
# 7728  A soap opera producer, director and makeup art...         2016.0
# 7739  Aided only by a tough female police officer, a...         2016.0
# 7772  Recovering alcoholic Talal wakes up inside a s...         2016.0
#
# [258 rows x 12 columns]

# %% [markdown]
# #### Show only the Titles of all TV Shows that were released in India only

# %%
netflix_df[(netflix_df['Category']=='TV Show')&(netflix_df['Country']=='India')]['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %% [markdown]
# **Show top 10 Directors who gave most number of movies and TV Shows to netflix**

# %%
netflix_df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Martin Scorsese           12
# Jay Chapman               12
# Youssef Chahine           12
# Steven Spielberg          10
# David Dhawan               9
# Robert Rodriguez           8
# Name: Director, dtype: int64

# %% [markdown]
# **Show all records where category is movies and Type is comedies or country is United Kingdom**

# %%
netflix_df[(netflix_df['Category']=='Movies') & (netflix_df['Type']== 'Comedies') | (netflix_df['Country']=='United Kingdom')]
# Out:
#      Show_Id Category                   Title           Director  \
# 19       s20    Movie                     '89                NaN
# 58       s59  TV Show             100% Hotter                NaN
# 82       s83    Movie     2036 Origin Unknown      Hasraf Dulull
# 85       s86  TV Show                21 Again                NaN
# 93       s94    Movie       27: Gone Too Soon  Simon Napier-Bell
# ...      ...      ...                     ...                ...
# 7670   s7669  TV Show  World War II in Colour                NaN
# 7671   s7670  TV Show  World's Busiest Cities                NaN
# 7688   s7687    Movie  XV: Beyond the Tryline   Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu        James Brown
# 7740   s7739  TV Show         Young Wallander                NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# 58    Daniel Palmer, Melissa Sophia, Karen Williams,...  United Kingdom
# 82    Katee Sackhoff, Ray Fearon, Julie Cox, Steven ...  United Kingdom
# 85                                         Laura Morgan  United Kingdom
# 93    Janis Joplin, Jimi Hendrix, Amy Winehouse, Jim...  United Kingdom
# ...                                                 ...             ...
# 7670                                      Robert Powell  United Kingdom
# 7671                 Anita Rani, Ade Adepitan, Dan Snow  United Kingdom
# 7688                                                NaN  United Kingdom
# 7725  Lily O'Regan, Jeannettsy Enriquez Borges, Joel...  United Kingdom
# 7740  Adam Pålsson, Richard Dillane, Leanne Best, El...  United Kingdom
#
#      Release_Date Rating  Duration  \
# 19     2018-05-16  TV-PG    87 min
# 58     2019-11-01  TV-14  1 Season
# 82     2018-12-20  TV-14    95 min
# 85     2020-07-01  TV-MA  1 Season
# 93     2018-05-01  TV-MA    70 min
# ...           ...    ...       ...
# 7670   2017-08-01  TV-MA  1 Season
# 7671   2019-02-01  TV-PG  1 Season
# 7688   2020-03-18  TV-14    91 min
# 7725   2017-12-31   TV-G    87 min
# 7740   2020-09-03  TV-MA  1 Season
#
#                                                    Type  \
# 19                                        Sports Movies
# 58    British TV Shows, International TV Shows, Real...
# 82                                     Sci-Fi & Fantasy
# 85                         British TV Shows, Reality TV
# 93                                        Documentaries
# ...                                                 ...
# 7670  British TV Shows, Docuseries, International TV...
# 7671                       British TV Shows, Docuseries
# 7688                       Documentaries, Sports Movies
# 7725                           Children & Family Movies
# 7740  Crime TV Shows, International TV Shows, TV Dramas
#
#                                             Description  Release_Years
# 19    Mixing old footage with interviews, this is th...         2018.0
# 58    A stylist, a hair designer and a makeup artist...         2019.0
# 82    Working with an artificial intelligence to inv...         2018.0
# 85    In a social experiment, a group of daughters s...         2020.0
# 93    Explore the circumstances surrounding the trag...         2018.0
# ...                                                 ...            ...
# 7670  Footage of the most dramatic moments from Worl...         2017.0
# 7671  From Moscow to Mexico City, three BBC journali...         2019.0
# 7688  Set against the 2015 Rugby World Cup, this doc...         2020.0
# 7725  A gifted young ballet dancer struggles to find...         2017.0
# 7740  An incendiary hate crime stirs civil unrest, f...         2020.0
#
# [397 rows x 12 columns]

# %% [markdown]
# #### Name the movies that "Tom Cruise" was a part of

# %%
netflix_new = netflix_df.dropna()
netflix_new[netflix_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description  Release_Years
# 3860  Through chance, human action, past history and...         2020.0
# 5071  A fast-talking yuppie is forced to slow down w...         2019.0

# %% [markdown]
# #### Different Ratings given in Netflix

# %%
netflix_df["Rating"].nunique()
# Out:
# 14

# %%
netflix_df["Rating"].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# #### Number of Tv Shows with 'R' rating after 2018

# %%
netflix_df[(netflix_df["Rating"] =='R') & (netflix_df['Release_Years']>2018)].shape
# Out:
# (450, 12)

# %% [markdown]
# #### Number of Tv Shows with 'TV-14' rating in 'Canada'

# %%
netflix_df[(netflix_df["Rating"] =='TV-14') & (netflix_df['Country']=='Canada')].shape
# Out:
# (23, 12)

# %% [markdown]
# **Maximum Duration of a TV Show or Movie**

# %%
netflix_df[["Duration_no","temp"]]=netflix_df['Duration'].str.split(' ',expand=True)
netflix_df.drop(columns='temp')
netflix_df[netflix_df['Category']=='Movie']['Duration_no'].max() #Maximum Duration for a movie
# Out:
# '99'

# %%
netflix_df[netflix_df['Category']=='TV Show']['Duration_no'].max()
# Out:
# '9'

# %% [markdown]
# #### Sorting Database on the basis of Years

# %%
netflix_df.sort_values(by='Release_Years')
# Out:
#      Show_Id Category                         Title              Director  \
# 7115   s7114    Movie          To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show               Dinner for Five                   NaN
# 5766   s5766    Movie                      Splatter             Joe Dante
# 3248   s3249    Movie       Just Another Love Story          Ole Bornedal
# 3840   s3841    Movie   Mad Ron's Prevues from Hell            Jim Monaco
# ...      ...      ...                           ...                   ...
# 3374   s3375  TV Show                      Kikoriki                   NaN
# 3492   s3493  TV Show           La Familia P. Luche                   NaN
# 3946   s3947  TV Show                         Maron                   NaN
# 5138   s5138  TV Show                  Red vs. Blue                   NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                   NaN
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
# ...                                                 ...            ...
# 3374                                      Igor Dmitriev            NaN
# 3492  Eugenio Derbez, Consuelo Duval, Luis Manuel Áv...  United States
# 3946  Marc Maron, Judd Hirsch, Josh Brener, Nora Zeh...  United States
# 5138  Burnie Burns, Jason Saldaña, Gustavo Sorola, G...  United States
# 6066  Luke Jurevicius, Craig Behenna, Charlotte Haml...      Australia
#
#      Release_Date Rating    Duration  \
# 7115   2008-01-01  TV-MA      81 min
# 1765   2008-02-04  TV-MA    1 Season
# 5766   2009-11-18  TV-MA      29 min
# 3248   2009-05-05  TV-MA     104 min
# 3840   2010-11-01     NR      84 min
# ...           ...    ...         ...
# 3374          NaT   TV-Y   2 Seasons
# 3492          NaT  TV-14   3 Seasons
# 3946          NaT  TV-MA   4 Seasons
# 5138          NaT     NR  13 Seasons
# 6066          NaT  TV-Y7   2 Seasons
#
#                                                    Type  \
# 7115              Dramas, Independent Movies, Thrillers
# 1765                       Stand-Up Comedy & Talk Shows
# 5766                                      Horror Movies
# 3248                       Dramas, International Movies
# 3840                         Cult Movies, Horror Movies
# ...                                                 ...
# 3374                                           Kids' TV
# 3492  International TV Shows, Spanish-Language TV Sh...
# 3946                                        TV Comedies
# 5138  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6066                              Kids' TV, TV Comedies
#
#                                             Description  Release_Years  \
# 7115  While covering a story in New York City, a Sea...         2008.0
# 1765  In each episode, four celebrities join host Jo...         2008.0
# 5766  After committing suicide, a washed-up rocker r...         2009.0
# 3248  When he causes a car accident that leaves a yo...         2009.0
# 3840  This collection cherry-picks trailers, forgott...         2010.0
# ...                                                 ...            ...
# 3374  A wacky rabbit and his gang of animal pals hav...            NaN
# 3492  This irreverent sitcom featues Ludovico, Feder...            NaN
# 3946  Marc Maron stars as Marc Maron, who interviews...            NaN
# 5138  This parody of first-person shooter games, mil...            NaN
# 6066  Imagine your worst fears, then multiply them: ...            NaN
#
#      Duration_no     temp
# 7115          81      min
# 1765           1   Season
# 5766          29      min
# 3248         104      min
# 3840          84      min
# ...          ...      ...
# 3374           2  Seasons
# 3492           3  Seasons
# 3946           4  Seasons
# 5138          13  Seasons
# 6066           2  Seasons
#
# [7789 rows x 14 columns]

# %% [markdown]
# #### Find all the instances where Category is 'Movie' and Type is 'Drama' or Category is 'TV Shows' and Type is 'Kids TV'

# %%
netflix_df[(netflix_df['Category']=="Movie") & (netflix_df['Type']=="Dramas") | (netflix_df['Category']=="TV Show") & (netflix_df['Type'].isin(["Kids' TV"]))]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 170   Gerard Butler, Gretchen Mol, Alison Brie, Will...
# 232   Ken Olin, Jill Eikenberry, Maureen Mueller, Gr...
# ...                                                 ...
# 7668  Haven Paschall, Alysha Deslorieux, Jessica Paq...
# 7717  Eileen Stevens, Alyson Leigh Rosenfeld, Sarah ...
# 7719  Sairaj, Devyani Dagaonkar, Ketan Singh, Mayur ...
# 7758  Apollo Costa, Gabriel Santana, Matheus Lustosa...
# 7761  Michael Johnston, Jessica Gee-George, Christin...
#
#                                             Country        Release_Date  \
# 4                                     United States     January 1, 2020
# 7                                     United States    November 1, 2019
# 111                                           Italy     October 1, 2020
# 170                           Canada, United States   December 15, 2019
# 232                                   United States     October 1, 2011
# ...                                             ...                 ...
# 7668                           Italy, United States       June 16, 2017
# 7717                                            NaN       June 23, 2018
# 7719                                            NaN        June 7, 2018
# 7758                                         Brazil   February 22, 2019
# 7761  United States, France, South Korea, Indonesia  September 13, 2018
#
#      Rating   Duration      Type  \
# 4     PG-13    123 min    Dramas
# 7         R    119 min    Dramas
# 111   TV-Y7  2 Seasons  Kids' TV
# 170       R    110 min    Dramas
# 232   TV-14     95 min    Dramas
# ...     ...        ...       ...
# 7668  TV-Y7  2 Seasons  Kids' TV
# 7717   TV-Y   1 Season  Kids' TV
# 7719  TV-Y7   1 Season  Kids' TV
# 7758  TV-PG  2 Seasons  Kids' TV
# 7761  TV-Y7  3 Seasons  Kids' TV
#
#                                             Description
# 4     A brilliant group of students become card-coun...
# 7     After one of his high school students attacks ...
# 111   Paw-esome tales abound when singing furry frie...
# 170   A ruthless corporate headhunter battles his ri...
# 232   After reckless teens kill an Amish child, a pr...
# ...                                                 ...
# 7668  The reality show "WOW!" engages the Winx in th...
# 7717  Friends Mai, Oto and Vik's games at the park b...
# 7719  With the mind of a human being, and the body o...
# 7758  Fading music biz veteran Zé realizes he has ju...
# 7761  Teen surfer Zak Storm is mysteriously transpor...
#
# [322 rows x 11 columns]
